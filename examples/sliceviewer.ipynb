# %% [markdown]
# Example of how to use the interactive sliceviewer.

# %%
from AB_ImVision import interactive_slice_viewer
import numpy as np

object = np.random.rand(10, 10, 10)
interactive_slice_viewer(object)
# Out:
# interactive(children=(IntSlider(value=0, description='Slice Index', max=9), Dropdown(description='Slice Direct…
